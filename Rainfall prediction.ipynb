# %%
import pandas as pd
df = pd.read_csv('weatherAus.csv')

# %%
df
# Out:
#               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 0       2008-12-01   Albury     13.4     22.9       0.6          NaN
# 1       2008-12-02   Albury      7.4     25.1       0.0          NaN
# 2       2008-12-03   Albury     12.9     25.7       0.0          NaN
# 3       2008-12-04   Albury      9.2     28.0       0.0          NaN
# 4       2008-12-05   Albury     17.5     32.3       1.0          NaN
# ...            ...      ...      ...      ...       ...          ...
# 145455  2017-06-21    Uluru      2.8     23.4       0.0          NaN
# 145456  2017-06-22    Uluru      3.6     25.3       0.0          NaN
# 145457  2017-06-23    Uluru      5.4     26.9       0.0          NaN
# 145458  2017-06-24    Uluru      7.8     27.0       0.0          NaN
# 145459  2017-06-25    Uluru     14.9      NaN       0.0          NaN
#
#         Sunshine WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  \
# ...

# %%
rain=df.loc[df['RainToday']=='Yes']
print(rain)
# Out:
#               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 9       2008-12-10   Albury     13.1     30.1       1.4          NaN
# 11      2008-12-12   Albury     15.9     21.7       2.2          NaN
# 12      2008-12-13   Albury     15.9     18.6      15.6          NaN
# 13      2008-12-14   Albury     12.6     21.0       3.6          NaN
# 17      2008-12-18   Albury     13.5     22.9      16.8          NaN
# ...            ...      ...      ...      ...       ...          ...
# 145325  2017-02-11    Uluru     22.2     39.4       6.2          NaN
# 145391  2017-04-18    Uluru     15.2     21.5       6.8          NaN
# 145392  2017-04-19    Uluru     17.7     26.9      12.6          NaN
# 145393  2017-04-20    Uluru     18.6     28.6      34.6          NaN
# 145394  2017-04-21    Uluru     18.1     29.6       3.8          NaN
#
#         Sunshine WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  \
# ...

# %%
df.dtypes
# Out:
# Date              object
# Location          object
# MinTemp          float64
# MaxTemp          float64
# Rainfall         float64
# Evaporation      float64
# Sunshine         float64
# WindGustDir       object
# WindGustSpeed    float64
# WindDir9am        object
# WindDir3pm        object
# WindSpeed9am     float64
# WindSpeed3pm     float64
# Humidity9am      float64
# Humidity3pm      float64
# Pressure9am      float64
# Pressure3pm      float64
# Cloud9am         float64
# Cloud3pm         float64
# Temp9am          float64
# Temp3pm          float64
# RainToday         object
# RainTomorrow      object
# dtype: object

# %%
df.dtypes
# Out:
# Date              object
# Location          object
# MinTemp          float64
# MaxTemp          float64
# Rainfall         float64
# Evaporation      float64
# Sunshine         float64
# WindGustDir       object
# WindGustSpeed    float64
# WindDir9am        object
# WindDir3pm        object
# WindSpeed9am     float64
# WindSpeed3pm     float64
# Humidity9am      float64
# Humidity3pm      float64
# Pressure9am      float64
# Pressure3pm      float64
# Cloud9am         float64
# Cloud3pm         float64
# Temp9am          float64
# Temp3pm          float64
# RainToday         object
# RainTomorrow      object
# dtype: object

# %%
df.shape
# Out:
# (145460, 23)

# %%
df.isnull().sum()
# Out:
# Date                 0
# Location             0
# MinTemp           1485
# MaxTemp           1261
# Rainfall          3261
# Evaporation      62790
# Sunshine         69835
# WindGustDir      10326
# WindGustSpeed    10263
# WindDir9am       10566
# WindDir3pm        4228
# WindSpeed9am      1767
# WindSpeed3pm      3062
# Humidity9am       2654
# Humidity3pm       4507
# Pressure9am      15065
# Pressure3pm      15028
# Cloud9am         55888
# Cloud3pm         59358
# Temp9am           1767
# Temp3pm           3609
# RainToday         3261
# RainTomorrow      3267
# dtype: int64

# %%
categorical_features = []
numerical_features = []

for feature in df.columns:
    if df[feature].dtype == 'object':
        categorical_features.append(feature)
    else:
        numerical_features.append(feature)

print('Categorical features:', categorical_features)
print('Numerical features:', numerical_features)
# Out:
# Categorical features: ['Date', 'Location', 'WindGustDir', 'WindDir9am', 'WindDir3pm', 'RainToday', 'RainTomorrow']
# Numerical features: ['MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation', 'Sunshine', 'WindGustSpeed', 'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm', 'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am', 'Temp3pm']

# %%
for feature in numerical_features:
    df[feature].fillna(df[feature].median(), inplace=True)
for feature in categorical_features:
    df[feature].fillna(method ='bfill', inplace=True)

# %%
df['RainTomorrow'].fillna(method = 'ffill', inplace = True)
df['WindGustDir'].fillna(method = 'ffill', inplace = True)

# %%
df.isnull().sum()
# Out:
# Date             0
# Location         0
# MinTemp          0
# MaxTemp          0
# Rainfall         0
# Evaporation      0
# Sunshine         0
# WindGustDir      0
# WindGustSpeed    0
# WindDir9am       0
# WindDir3pm       0
# WindSpeed9am     0
# WindSpeed3pm     0
# Humidity9am      0
# Humidity3pm      0
# Pressure9am      0
# Pressure3pm      0
# Cloud9am         0
# Cloud3pm         0
# Temp9am          0
# Temp3pm          0
# RainToday        0
# RainTomorrow     0
# dtype: int64

# %%
df['Location'].value_counts()
# Out:
# Canberra            3436
# Sydney              3344
# Darwin              3193
# Melbourne           3193
# Brisbane            3193
# Adelaide            3193
# Perth               3193
# Hobart              3193
# Albany              3040
# MountGambier        3040
# Ballarat            3040
# Townsville          3040
# GoldCoast           3040
# Cairns              3040
# Launceston          3040
# AliceSprings        3040
# Bendigo             3040
# Albury              3040
# MountGinini         3040
# Wollongong          3040
# Newcastle           3039
# Tuggeranong         3039
# Penrith             3039
# Woomera             3009
# Nuriootpa           3009
# Cobar               3009
# CoffsHarbour        3009
# Moree               3009
# Sale                3009
# PerthAirport        3009
# PearceRAAF          3009
# Witchcliffe         3009
# BadgerysCreek       3009
# Mildura             3009
# NorfolkIsland       3009
# MelbourneAirport    3009
# Richmond            3009
# ...

# %%
categorical_features
# Out:
# ['Date',
#  'Location',
#  'WindGustDir',
#  'WindDir9am',
#  'WindDir3pm',
#  'RainToday',
#  'RainTomorrow']

# %%
category = categorical_features
category.pop(0)
# Out:
# 'Date'

# %%
from matplotlib import pyplot as plt
data = df['RainToday'].value_counts()
data
plt.bar(data.index, data.values, color=['green','yellow'])
# Out:
# <BarContainer object of 2 artists>

# %%
data1 = df['RainTomorrow'].value_counts()
data1
plt.bar(data1.index, data1.values, color=['green','yellow'])
# Out:
# <BarContainer object of 2 artists>

# %%
plt.hist(df['MaxTemp'], edgecolor='white');

# %%
data = df['Location'].value_counts()
plt.pie(data.values, labels = data.index, autopct = '%1.1f%%');

# %%
import numpy as np
N = 15
ind = np.arange(N)
width = 0.25
xval = df['RainToday'].head(15)
bar1 = plt.bar(ind, xval, width, color='violet')

yval = df['RainTomorrow'].head(15)
bar2 = plt.bar(ind+width, yval, width, color='orange')

plt.xlabel('RainToday')
plt.ylabel('RainTommorow')
plt.xticks(ind+width, df['RainToday'].head(15))
plt.legend((bar1, bar2), ('RainToday', 'RainTomorrow'))

# %%
from sklearn.preprocessing import LabelEncoder
for feature in categorical_features:
    le = LabelEncoder()
    df[feature] = le.fit_transform(df[feature])
    # get the mapping of original labels to encoded labels
    if feature == 'Location':
        color_label_location = dict(zip(le.classes_, le.transform(le.classes_)))
    elif feature == 'WindGustDir':
        size_label_windGust = dict(zip(le.classes_, le.transform(le.classes_)))
    elif feature == 'WindDir9am':
        shape_label_windir9 = dict(zip(le.classes_, le.transform(le.classes_)))
    elif feature == 'WindDir3pm':
        shape_label_windir3 = dict(zip(le.classes_, le.transform(le.classes_)))    
    elif feature == 'RainToday':
        shape_label_rainToday = dict(zip(le.classes_, le.transform(le.classes_)))     


print("Location Label Dictionary:", color_label_location)
print("WindGustDIr Label Dictionary:", size_label_windGust)
print("WindDir9am Label Dictionary:", shape_label_windir9) 
print("WindDir3pm Label Dictionary:", shape_label_windir3) 
print("RainToday Label Dictionary:", shape_label_rainToday)
# Out:
# Location Label Dictionary: {'Adelaide': 0, 'Albany': 1, 'Albury': 2, 'AliceSprings': 3, 'BadgerysCreek': 4, 'Ballarat': 5, 'Bendigo': 6, 'Brisbane': 7, 'Cairns': 8, 'Canberra': 9, 'Cobar': 10, 'CoffsHarbour': 11, 'Dartmoor': 12, 'Darwin': 13, 'GoldCoast': 14, 'Hobart': 15, 'Katherine': 16, 'Launceston': 17, 'Melbourne': 18, 'MelbourneAirport': 19, 'Mildura': 20, 'Moree': 21, 'MountGambier': 22, 'MountGinini': 23, 'Newcastle': 24, 'Nhil': 25, 'NorahHead': 26, 'NorfolkIsland': 27, 'Nuriootpa': 28, 'PearceRAAF': 29, 'Penrith': 30, 'Perth': 31, 'PerthAirport': 32, 'Portland': 33, 'Richmond': 34, 'Sale': 35, 'SalmonGums': 36, 'Sydney': 37, 'SydneyAirport': 38, 'Townsville': 39, 'Tuggeranong': 40, 'Uluru': 41, 'WaggaWagga': 42, 'Walpole': 43, 'Watsonia': 44, 'Williamtown': 45, 'Witchcliffe': 46, 'Wollongong': 47, 'Woomera': 48}
# ...

# %%
df['Date']=pd.to_datetime(df['Date'], format = "%Y-%m-%dT", errors = 'coerce')

# %%
df['Date_month']=df['Date'].dt.month
df['Date_day']=df['Date'].dt.day
df['Date_year']=df['Date'].dt.year#'Date_month','Date_day','Date_year'

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report, roc_curve, auc
import matplotlib.pyplot as plt

# %%
x = df[['Rainfall', 'Humidity3pm', 'Humidity9am', 'Pressure9am', 'Pressure3pm', 'WindGustSpeed', 'Sunshine','Date_month','Date_day','Date_year','Location']]#input variable
y = df['RainToday']#target variable

# %%
z_threshold = 3

# iterate over each column
for column in x:
    # calculate the z-scores for the column
    z_scores = np.abs((df[column] - df[column].mean()) / df[column].std())

    # identify the outliers
    outliers = df[z_scores > z_threshold][column]

    # remove the outliers
    df = df.drop(outliers.index)

# %%
import matplotlib.pyplot as plt
for col in x:
    plt.figure()
    plt.boxplot(df[col])
    plt.title(col)
    plt.show()

# %%
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier()
rfc.fit(x, y)
importances = rfc.feature_importances_

# create dataframe of feature importances and sort by importance
feature_importances = pd.DataFrame({'feature': x.columns, 'importance': importances})
feature_importances = feature_importances.sort_values('importance', ascending=False)

# select the 6 most important features
selected_features = feature_importances['feature'][:8].tolist()

# %%
print(selected_features)
# Out:
# ['Rainfall', 'Humidity3pm', 'Humidity9am', 'Pressure3pm', 'Pressure9am', 'Sunshine', 'WindGustSpeed', 'Date_day']

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.05, random_state=1)

# %%
standard_Scalar = StandardScaler()
x_train = standard_Scalar.fit_transform(x_train)
x_test = standard_Scalar.transform(x_test)

# %%
pip install optuna
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.neighbors import KNeighborsClassifier
def objective(trial):
    n_neighbors = trial.suggest_int('KNN_n_neighbors', 2, 16, log=False)
    classifier_obj = KNeighborsClassifier(n_neighbors=n_neighbors)
    classifier_obj.fit(x_train, y_train)
    accuracy = classifier_obj.score(x_test, y_test)
    return accuracy
import optuna
study_KNN = optuna.create_study(direction='maximize')
study_KNN.optimize(objective, n_trials=1)
print(study_KNN.best_trial)
KNN_model = KNeighborsClassifier(n_neighbors=study_KNN.best_trial.params['KNN_n_neighbors'])
KNN_model.fit(x_train, y_train)

KNN_train, KNN_test = KNN_model.score(x_train, y_train), KNN_model.score(x_test, y_test)

print(f"Train Score: {KNN_train}")
print(f"Test Score: {KNN_test}")
# Out:
# [I 2023-04-20 11:11:27,214] A new study created in memory with name: no-name-e94bb4c2-22aa-47ce-a416-d003997fb4b0
# [I 2023-04-20 11:11:36,525] Trial 0 finished with value: 0.8823044135844906 and parameters: {'KNN_n_neighbors': 9}. Best is trial 0 with value: 0.8823044135844906.
# FrozenTrial(number=0, state=TrialState.COMPLETE, values=[0.8823044135844906], datetime_start=datetime.datetime(2023, 4, 20, 11, 11, 27, 217128), datetime_complete=datetime.datetime(2023, 4, 20, 11, 11, 36, 525945), params={'KNN_n_neighbors': 9}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'KNN_n_neighbors': IntDistribution(high=16, log=False, low=2, step=1)}, trial_id=0, value=None)
# Train Score: 0.90507790168395
# Test Score: 0.8823044135844906

# %%
from sklearn.tree import DecisionTreeClassifier
clfd = DecisionTreeClassifier(criterion ="entropy", max_depth = 4)
clfd.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=4)

# %%
def objective(trial):
    dt_max_depth = trial.suggest_int('dt_max_depth', 2, 32, log=False)
    dt_max_features = trial.suggest_int('dt_max_features', 2, 10, log=False)
    classifier_obj = DecisionTreeClassifier(max_features = dt_max_features, max_depth = dt_max_depth)
    classifier_obj.fit(x_train, y_train)
    accuracy = classifier_obj.score(x_test, y_test)
    return accuracy

# %%
study_dt = optuna.create_study(direction='maximize')
study_dt.optimize(objective, n_trials=30)
print(study_dt.best_trial)
# Out:
# [I 2023-04-20 11:23:51,441] A new study created in memory with name: no-name-540c6ee1-d4e0-4900-86cc-12d97d267244
# [I 2023-04-20 11:23:51,841] Trial 0 finished with value: 0.9855630413859481 and parameters: {'dt_max_depth': 19, 'dt_max_features': 5}. Best is trial 0 with value: 0.9855630413859481.
# [I 2023-04-20 11:23:52,169] Trial 1 finished with value: 0.9832256290389111 and parameters: {'dt_max_depth': 30, 'dt_max_features': 4}. Best is trial 0 with value: 0.9855630413859481.
# [I 2023-04-20 11:23:52,430] Trial 2 finished with value: 0.9848755671662313 and parameters: {'dt_max_depth': 23, 'dt_max_features': 3}. Best is trial 0 with value: 0.9855630413859481.
# [I 2023-04-20 11:23:52,640] Trial 3 finished with value: 0.966038773545992 and parameters: {'dt_max_depth': 9, 'dt_max_features': 3}. Best is trial 0 with value: 0.9855630413859481.
# ...

# %%
dt = DecisionTreeClassifier(max_features = study_dt.best_trial.params['dt_max_features'], max_depth = study_dt.best_trial.params['dt_max_depth'])
dt.fit(x_train, y_train)

dt_train, dt_test = dt.score(x_train, y_train), dt.score(x_test, y_test)

print(f"Train Score: {dt_train}")
print(f"Test Score: {dt_test}")
# Out:
# Train Score: 0.9914970293877138
# Test Score: 0.9907878454557955

# %%
from sklearn.cluster import KMeans
import numpy as np
from sklearn.cluster import KMeans
wcss=[]
for i in range(1,11):
    kmeans = KMeans(n_clusters= i, init='k-means++', random_state=42)
    print(kmeans)
    kmeans.fit(x)
    wcss.append(kmeans.inertia_)
# Out:
# KMeans(n_clusters=1, random_state=42)
# C:\Users\srika\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# KMeans(n_clusters=2, random_state=42)
# C:\Users\srika\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# KMeans(n_clusters=3, random_state=42)
# C:\Users\srika\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# KMeans(n_clusters=4, random_state=42)
# ...

# %%
plt.plot(range(1,11), wcss)
plt.title('The Elbow Method')
plt.xlabel('no of clusters')
plt.ylabel('wcss')
plt.show()

# %%
from sklearn.neighbors import KNeighborsClassifier

k = 5  # number of neighbors to consider
clf = KNeighborsClassifier(n_neighbors=k)
clf.fit(x_train, y_train)
y_pred = clf.predict(x_test)
from sklearn.metrics import accuracy_score

accuracy = accuracy_score(y_test, y_pred)
print('Accuracy: {:.2f}%'.format(accuracy * 100))
# Out:
# Accuracy: 88.29%

# %%
import joblib

# %%
joblib.dump(dt, 'DecisionTreeClassifier')
# Out:
# ['DecisionTreeClassifier']

# %%
dt_ = joblib.load('DecisionTreeClassifier')

# %%
dt_
# Out:
# DecisionTreeClassifier(max_depth=9, max_features=7)

# %%
dt_.predict(x_test)
# Out:
# array([1, 0, 0, ..., 0, 0, 0])

# %%
feature_names = ['Rainfall', 'Humidity3pm', 'Humidity9am', 'Pressure9am', 'Pressure3pm', 'WindGustSpeed', 'Sunshine','Date_month','Date_day','Date_year','Location']

# create an empty dictionary to store the user input values
user_input_dict = {}

# loop through the feature names and get user input for each one
for feature in feature_names:
    value = input("Enter value for {}: ".format(feature))
    user_input_dict[feature] = float(value)

# convert the input dictionary to a numpy array and reshape to match the original shape
user_input = np.array(list(user_input_dict.values()), dtype=np.float32).reshape(1, -1)
# Out:
# Enter value for Rainfall: 0.9
# Enter value for Humidity3pm: 5
# Enter value for Humidity9am: 9
# Enter value for Pressure9am: 2000
# Enter value for Pressure3pm: 3000
# Enter value for WindGustSpeed: 70
# Enter value for Sunshine: 22
# Enter value for Date_month: 4
# Enter value for Date_day: 22
# Enter value for Date_year: 2023
# Enter value for Location: 16

# %%
print(user_input)
# Out:
# [[9.000e-01 5.000e+00 9.000e+00 2.000e+03 3.000e+03 7.000e+01 2.200e+01
#   4.000e+00 2.200e+01 2.023e+03 1.600e+01]]

# %%
scaler = StandardScaler()
user_input = scaler.fit_transform(user_input)

# make predictions
pred = dt_.predict(user_input)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[39], line 5
#       2 user_input = scaler.fit_transform(user_input)
#       4 # make predictions
# ----> 5 pred = dt_.predict(user_input)
#
# File ~\anaconda3\lib\site-packages\sklearn\tree\_classes.py:426, in BaseDecisionTree.predict(self, X, check_input)
#     403 """Predict class or regression value for X.
#     404
#     405 For a classification model, the predicted class for each sample in X is
#    (...)
#     423     The predicted classes, or the predict values.
#     424 """
#     425 check_is_fitted(self)
# --> 426 X = self._validate_X_predict(X, check_input)
#     427 proba = self.tree_.predict(X)
#     428 n_samples = X.shape[0]
#
# File ~\anaconda3\lib\site-packages\sklearn\tree\_classes.py:392, in BaseDecisionTree._validate_X_predict(self, X, check_input)
# ...

# %%
print(pred)
# Out:
# [1]

# %%
if pred[0] == 0:
    print("It will not rain today")
if pred[0] == 1:
    print("It will rain today")
# Out:
# It will rain today

# %%
x1 = df[['Rainfall', 'Humidity3pm', 'Humidity9am', 'Pressure9am', 'Pressure3pm', 'WindGustSpeed', 'Sunshine','Date_month','Date_day','Date_year','Location']]#input variable
y1 = df['RainTomorrow']#target variable

# %%
x1_train, x1_test, y1_train, y1_test = train_test_split(x1, y1, test_size = 0.05, random_state=1)

# %%
standard_Scalar = StandardScaler()
x1_train = standard_Scalar.fit_transform(x1_train)
x1_test = standard_Scalar.transform(x1_test)

# %%
from sklearn.neighbors import KNeighborsClassifier
def objective(trial):
    n_neighbors = trial.suggest_int('KNN_n_neighbors', 2, 16, log=False)
    classifier_obj = KNeighborsClassifier(n_neighbors=n_neighbors)
    classifier_obj.fit(x1_train, y1_train)
    accuracy = classifier_obj.score(x1_test, y1_test)
    return accuracy
import optuna
study_KNN = optuna.create_study(direction='maximize')
study_KNN.optimize(objective, n_trials=1)
print(study_KNN.best_trial)
KNN_model = KNeighborsClassifier(n_neighbors=study_KNN.best_trial.params['KNN_n_neighbors'])
KNN_model.fit(x1_train, y1_train)

KNN_train, KNN_test = KNN_model.score(x1_train, y1_train), KNN_model.score(x1_test, y1_test)

print(f"Train Score: {KNN_train}")
print(f"Test Score: {KNN_test}")
# Out:
# [I 2023-04-20 00:25:09,992] A new study created in memory with name: no-name-8337488c-dbe5-4af6-8af4-083b63c9ed92
# [I 2023-04-20 00:25:13,274] Trial 0 finished with value: 0.8332187542967139 and parameters: {'KNN_n_neighbors': 15}. Best is trial 0 with value: 0.8332187542967139.
# FrozenTrial(number=0, state=TrialState.COMPLETE, values=[0.8332187542967139], datetime_start=datetime.datetime(2023, 4, 20, 0, 25, 9, 994801), datetime_complete=datetime.datetime(2023, 4, 20, 0, 25, 13, 274832), params={'KNN_n_neighbors': 15}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'KNN_n_neighbors': IntDistribution(high=16, log=False, low=2, step=1)}, trial_id=0, value=None)
# Train Score: 0.8509483525946724
# Test Score: 0.8332187542967139

# %%
joblib.dump(KNN_model, 'KNeigborsClassifier')
# Out:
# ['KNeigborsClassifier']

# %%
knn_ = joblib.load('KNeigborsClassifier')

# %%
knn_
# Out:
# KNeighborsClassifier(n_neighbors=15)

# %%
knn_.predict(x1_test)
# Out:
# array([0, 0, 0, ..., 0, 0, 1])

# %%
feature_names = ['Rainfall', 'Humidity3pm', 'Humidity9am', 'Pressure9am', 'Pressure3pm', 'WindGustSpeed', 'Sunshine','Date_month','Date_day','Date_year','Location']

# create an empty dictionary to store the user input values
user_input_dict = {}

# loop through the feature names and get user input for each one
for feature in feature_names:
    value = input("Enter value for {}: ".format(feature))
    user_input_dict[feature] = float(value)

# convert the input dictionary to a numpy array and reshape to match the original shape
user_input1 = np.array(list(user_input_dict.values()), dtype=np.float32).reshape(1, -1)
# Out:
# Enter value for Rainfall: 1.1
# Enter value for Humidity3pm: 24
# Enter value for Humidity9am: 50
# Enter value for Pressure9am: 1000
# Enter value for Pressure3pm: 1005
# Enter value for WindGustSpeed: 45
# Enter value for Sunshine: 8.5
# Enter value for Date_month: 7
# Enter value for Date_day: 23
# Enter value for Date_year: 2020

# %%
print(user_input)
# Out:
# [[1.100e+00 2.400e+01 5.000e+01 1.000e+03 1.005e+03 4.500e+01 8.500e+00
#   7.000e+00 2.300e+01 2.020e+03]]

# %%
scaler = StandardScaler()
user_input1 = scaler.fit_transform(user_input1)

# make predictions
pred1 = knn_.predict(user_input1)

# %%
print(pred1)
# Out:
# [0]

# %%
if pred1[0] == 0:
    print("It will not rain tomorrow")
if pred1[0] == 1:
    print("It will rain tomorrow")
# Out:
# It will not rain tomorrow
